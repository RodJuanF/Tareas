# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dn = pd.read_excel("Datos Estaciones AMB.xlsx",sheet_name="Normal (2)",usecols=[0,2])

# %%
dn = dn.dropna().drop(dn[dn["PM2.5"]=="NoData"].index).drop(dn[dn["PM2.5"]=="<Samp"].index).drop(dn[dn["PM2.5"]=="---"].index)

# %%
dn.info()
print(dn)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7086 entries, 0 to 8039
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date&Time  7086 non-null   datetime64[ns]
#  1   PM2.5      7086 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 166.1+ KB
#                Date&Time PM2.5
# 0    2018-10-01 00:00:00   6.4
# 1    2018-10-01 01:00:00   6.4
# 2    2018-10-01 02:00:00   6.7
# 3    2018-10-01 03:00:00     6
# 4    2018-10-01 04:00:00   7.3
# ...                  ...   ...
# 8035 2019-08-31 19:00:00  20.4
# 8036 2019-08-31 20:00:00  18.7
# 8037 2019-08-31 21:00:00  22.8
# 8038 2019-08-31 22:00:00  25.2
# 8039 2019-08-31 23:00:00    18
#
# [7086 rows x 2 columns]

# %%
fig, axes = plt.subplots(figsize=(10,6))
axes.scatter(dn["Date&Time"],dn["PM2.5"])
